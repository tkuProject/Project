# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup,NavigableString, Tag
import time
import requests
import re
import csv
from selenium.webdriver.common.by import By
import pandas as pd
import os

headers = {'content-type': 'text/html; charset=UTF-8','user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36(KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}
#s = Service(r"/usr/local/bin/chromedriver") #使用chromedriver、selenium
driver = webdriver.Chrome()
    
driver.get("https://www.cardu.com.tw/") #自動打開網頁（不要關）
    
time.sleep(5) #暫停
    
soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
#print(soup.prettify())  #輸出排版後的HTML內容

#爬卡排行的名稱
card_ranking_type = [] 
results1 = soup.find_all('div', class_='text-center')
for results in results1:
    result = results.find('a').get('title')
    card_ranking_type.append(result)
    #print(result) #測試抓到的卡排行
    
card_ranking_type.pop(0) #頭兩個不需要 因此刪除
card_ranking_type.pop(0)
#for i in range(len(card_ranking_type)):
    #print(card_ranking_type[i])

#爬卡排行的網址
card_ranking_link = []
results1 = soup.find_all('div', class_='text-center')
for results in results1:
    result = results.find('a').get('href')
    result = 'https://www.cardu.com.tw/'+result
    card_ranking_link.append(result)
    #print(result)

card_ranking_link.pop(0) #頭兩個不需要 因此刪除
card_ranking_link.pop(0)
#for i in range(len(card_ranking_link)):
    #print(card_ranking_link[i])

ranking_dict = {
    '排行名稱':card_ranking_type,
    '排行連結':card_ranking_link,
}
df = pd.DataFrame(ranking_dict)
folder_name = 'carducsv'
path = "/Users/takoyaki/Downloads/專題爬蟲" 
folder_path = os.path.join(path, folder_name)
if not os.path.isdir(folder_path):
    os.makedirs(folder_path, mode=0o777)
path0 = str(path+'/'+folder_name+"/")
#path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
df.to_csv(path0+'icardu排行.csv', index = False)


for k in range(len(card_ranking_link)):
    
    card_name1 = [] #卡名無門檻
    card_name2 = [] #卡名有門檻
    card_name = [] #卡名一般排行
    card_link1 = [] #卡連結無門檻
    card_link2 = [] #卡連結有門檻
    card_link = [] #卡連結一般排行
    #一般
    block_name = []
    block_one = [] #國內回饋
    block_two = [] #國外回饋
    block_three = [] #其他卡片
    #無回饋
    block_one1 = [] #國內回饋
    block_two1 = [] #國外回饋
    block_three1 = [] #其他卡片
    #有回饋
    block_one2 = [] #國內回饋
    block_two2 = [] #國外回饋
    block_three2 = [] #其他卡片
    
    print('☆'+card_ranking_type[k])
    driver.get(card_ranking_link[k]) #自動打開網頁（不要關）
    time.sleep(3) #暫停   
    soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
    
    results = soup.find_all('div', class_='col-md text-center col-4')
    for result in results:
        print(result.text)
        block_name.append(result.text)
    
    if card_ranking_type[k] == '現金回饋':
        
        button= driver.find_element(By.ID, "goodSet-tab") #打開有門檻
        button.click()
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
        
        i=0
        results = soup.find_all('div', class_='col-md-11 wx-100-ph')
        for result in results:
            name = result.find('h5', class_='money_main mb-0') #卡名
            link = result.find('a').get('href') #卡連結
            
            if i<10: #無門檻
                card_name1.append(name.text)
                card_link1.append('https://www.cardu.com.tw'+link[2:])
            elif i==10: #有門檻換行
                print('\n')
                card_name2.append(name.text)
                card_link2.append('https://www.cardu.com.tw'+link[2:])
            elif i>10: #有門檻
                card_name2.append(name.text)
                card_link2.append('https://www.cardu.com.tw'+link[2:])
            print(name.text)
            print('https://www.cardu.com.tw'+link[2:])
            i+=1
        results=soup.find_all('div', class_='row w-h-100') #幾張卡
        
        j=0
        for result in results:
            if j < 10: #無門檻
                print(j)
                i = 0
                result1 = result.find_all('div', class_='col-md hv-center phone_block col-4 py-2 pc_rank_txt') #國內回饋+其他卡片
                for re in result1:
                    if i == 0:
                        print(block_name[0] +':'+ re.find('p').text)
                        block_one1.append(re.find('p').text) #國內回饋
                    else:
                        print(block_name[2] +':'+ re.find('p').text)
                        block_three1.append(re.find('p').text) #其他卡片
                    i+=1
                    
                result2 = result.find('div',class_='col-md hv-center border-left border-right phone_block col-4 py-2 pc_rank_txt') #國外回饋
                print(block_name[1] +':'+ result2.find('p').text)
                block_two1.append(result2.find('p').text)
                
            elif j == 10: #換行
                print(j)
                i = 0
                result1 = result.find_all('div', class_='col-md col-4 hv-center phone_block pc_rank_txt') #國內回饋+其他卡片
                for re in result1:
                    if i == 0:
                        print(block_name[0] +':'+ re.find('p').text)
                        block_one2.append(re.find('p').text) #國內回饋
                    else:
                        print(block_name[2] +':'+ re.find('p').text)
                        block_three2.append(re.find('p').text) #其他卡片 
                    i+=1
                    
                result2 = result.find('div',class_='col-md col-4 hv-center border-left border-right phone_block pc_rank_txt') #國外回饋
                print(block_name[1] +':'+ result2.find('p').text)
                block_two2.append(result2.find('p').text)
                print('\n')
                
            elif j > 10: #有門檻
                print(j)
                i = 0
                result1 = result.find_all('div', class_='col-md col-4 hv-center phone_block pc_rank_txt') #國內回饋+其他卡片
                for re in result1:
                    if i == 0:
                        print(block_name[0] +':'+ re.find('p').text)
                        block_one2.append(re.find('p').text) #國內回饋
                    else:
                        print(block_name[2] +':'+ re.find('p').text)
                        block_three2.append(re.find('p').text) #其他卡片
                    i+=1
                    
                result2 = result.find('div',class_='col-md col-4 hv-center border-left border-right phone_block pc_rank_txt') #國外回饋
                print(block_name[1] +':'+ result2.find('p').text)
                block_two2.append(result2.find('p').text)
                
            j+=1  
            
        ranking_card_dict1 = { #無門檻
            '卡名':card_name1,
            '卡連結':card_link1,
            block_name[0]:block_one1,
            block_name[1]:block_two1,
            block_name[2]:block_three1
        }
        ranking_card_dict2 = { #有門檻
            '卡名':card_name2,
            '卡連結':card_link2,
            block_name[0]:block_one2,
            block_name[1]:block_two2,
            block_name[2]:block_three2
        }
        
        df1 = pd.DataFrame(ranking_card_dict1)
        df2 = pd.DataFrame(ranking_card_dict2)
        folder_name = 'carducsv'
        path = "/Users/takoyaki/Downloads/專題爬蟲"
        #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
        folder_path = os.path.join(path, folder_name)
        if not os.path.isdir(folder_path):
            os.makedirs(folder_path, mode=0o777)
        path0 = str(path+'/'+folder_name+"/")
        df1.to_csv(path0+'cardu'+card_ranking_type[k]+'無門檻排行.csv', index = False)
        df2.to_csv(path0+'cardu'+card_ranking_type[k]+'有門檻排行.csv', index = False)
        print('\n')
    else:
        results = soup.find_all('div', class_='col-md-11 wx-100-ph')
        for result in results:
            name = result.find('h5', class_='money_main mb-0')
            link = result.find('a').get('href')
            print(name.text)
            card_name.append(name.text)
            card_link.append('https://www.cardu.com.tw'+link[2:])
            print('https://www.cardu.com.tw'+link[2:])
            
        results=soup.find_all('div', class_='row w-h-100')
        for result in results:
            result1 = result.find_all('div', class_='col-md hv-center phone_block col-4 py-2 pc_rank_txt') #國內回饋+其他卡片
            i = 0
            for re in result1:
                if i == 0:
                    print(block_name[0] +':'+ re.find('p').text)
                    block_one.append(re.find('p').text) #國內回饋
                else:
                    print(block_name[2] +':'+ re.find('p').text)
                    block_three.append(re.find('p').text) #其他卡片
                i+=1
                
            result2 = result.find('div',class_='col-md hv-center border-left border-right phone_block col-4 py-2 pc_rank_txt') #國外回饋
            print(block_name[1] +':'+ result2.find('p').text)
            block_two.append(result2.find('p').text)
            
        ranking_card_dict = { #一般
            '卡名':card_name,
            '卡連結':card_link,
            block_name[0]:block_one,
            block_name[1]:block_two,
            block_name[2]:block_three
        }
        df = pd.DataFrame(ranking_card_dict)
        
        folder_name = 'carducsv'
        path = "/Users/takoyaki/Downloads/專題爬蟲"  

        folder_path = os.path.join(path, folder_name)
        if not os.path.isdir(folder_path):
            os.makedirs(folder_path, mode=0o777)
        path0 = str(path+'/'+folder_name+"/")
        #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
        df.to_csv(path0+'cardu'+card_ranking_type[k]+'排行.csv', index = False)
        print('\n')
    
    if card_ranking_type[k] == '現金回饋':
        for i in range(len(card_link1)+len(card_link2)):
            if i<10: #無門檻
                driver.get(card_link1[i]) #自動打開網頁（不要關）
                print(card_name1[i])
                name = card_name1[i]
            else: #有門檻
                driver.get(card_link2[i-10]) #自動打開網頁（不要關）
                print(card_name2[i-10])
                name = card_name2[i-10]
            time.sleep(3) #暫停
            soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
            
            #卡圖片
            card_img = []
            result = soup.find('img', class_='ccard_img')
            if result !=None:
                card_img.append(result.get('src'))
                print(result.get('src'))
                
                #申請連結
                card_apply_link = []
                result = soup.find('a', class_='btn btn-block warning-layered btnOver')
                if result != None:
                    card_apply_link.append(result.get('href'))
                    print(result.get('href'))
                else:
                    card_apply_link.append('無')
                           
                #優惠
                summary_title = []
                summary_text = []
                results = soup.find_all('div', class_='col-md-6 py-1')
                for result in results:
                    print(result.text)
                    summary_text.append(result.text[:-1])
                    summary_title.append('特色')
                           
                #全部權益           
                button= driver.find_element(By.ID, "special_3-tab") 
                button.click()
                time.sleep(2)  
                soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                           
                #上標題
                title = []
                result = soup.find('form', class_='credit_boot')
                result1 = result.find_all('th')
                for result in result1:
                    print(result.text[:4])
                    title.append(result.text[:4])
                    
                #內文
                title_list = [] #標題
                text_list = [] #內容
                #result2 = soup.find('table')
                #print(result2)
                result3 = soup.find('div', id ='special_3')
                result2 = result3.find('tbody')
                #print(result2)
                result2 = result2.find_all('tr')
                for result in result2:
                    i = 0
                    results = result.find_all('td')
                    for result in results:
                        if i == 0:
                            print(result.find('label').text)
                            title_list.append(result.find('label').text)
                        else:
                            print(result.text)
                            text_list.append(result.text)
                        i+=1
                keyword='、'.join(summary_text) #把大標當關鍵字
    
                card_dict = { 
                    '卡圖片':card_img,
                    '申請連結':card_apply_link,
                    summary_title[0]:keyword
                }
                
                card_dict1={
                    title[0]:title_list,
                    title[1]:text_list
                }
                
                df1 = pd.DataFrame(card_dict1)
                df = pd.DataFrame(card_dict)
                folder_name = 'carducsv'+card_ranking_type[k]
                path = "/Users/takoyaki/Downloads/專題爬蟲"  
        
                folder_path = os.path.join(path, folder_name)
                if not os.path.isdir(folder_path):
                    os.makedirs(folder_path, mode=0o777)
                path0 = str(path+'/'+folder_name+"/")
                #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
                df1.to_csv(path0+'cardu'+name+'權益.csv', index = False)
                df.to_csv(path0+'cardu'+name+'.csv', index = False)
                
            else:
                cards = soup.find_all('a', class_='card_name my-2')
                for card in cards:
                    card_img = []
                    driver.get('https://www.cardu.com.tw'+card.get('href')[2:]) #自動打開網頁（不要關）
                    time.sleep(3) #暫停
                    soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                    
                    result = soup.find('img', class_='ccard_img')
                    card_img.append(result.get('src'))
                    print(result.get('src'))
                    
                    #申請連結
                    card_apply_link = []
                    result = soup.find('a', class_='btn btn-block warning-layered btnOver')
                    if result != None:
                        card_apply_link.append(result.get('href'))
                        print(result.get('href'))
                    else:
                        card_apply_link.append('無')
                               
                    #優惠
                    summary_title = []
                    summary_text = []
                    results = soup.find_all('div', class_='col-md-6 py-1')
                    for result in results:
                        print(result.text)
                        summary_text.append(result.text[:-1])
                        summary_title.append('特色')
                               
                    #全部權益           
                    button= driver.find_element(By.ID, "special_3-tab") 
                    button.click()
                    time.sleep(2)  
                    soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                               
                    #上標題
                    title = []
                    result = soup.find('form', class_='credit_boot')
                    result1 = result.find_all('th')
                    for result in result1:
                        print(result.text[:4])
                        title.append(result.text[:4])
                        
                    #內文
                    title_list = [] #標題
                    text_list = [] #內容
                    #result2 = soup.find('table')
                    #print(result2)
                    result3 = soup.find('div', id ='special_3')
                    result2 = result3.find('tbody')
                    #print(result2)
                    result2 = result2.find_all('tr')
                    for result in result2:
                        i = 0
                        results = result.find_all('td')
                        for result in results:
                            if i == 0:
                                print(result.find('label').text)
                                title_list.append(result.find('label').text)
                            else:
                                print(result.text)
                                text_list.append(result.text)
                            i+=1
                    keyword='、'.join(summary_text) #把大標當關鍵字
        
                    card_dict = { 
                        '卡圖片':card_img,
                        '申請連結':card_apply_link,
                        summary_title[0]:keyword
                    }
                    
                    card_dict1={
                        title[0]:title_list,
                        title[1]:text_list
                    }
                    
                    df1 = pd.DataFrame(card_dict1)
                    df = pd.DataFrame(card_dict)
                    
                    folder_name = 'carducsv'+card_ranking_type[k]
                    path = "/Users/takoyaki/Downloads/專題爬蟲"  
            
                    folder_path = os.path.join(path, folder_name)
                    if not os.path.isdir(folder_path):
                        os.makedirs(folder_path, mode=0o777)
                    path0 = str(path+'/'+folder_name+"/")
                    
                    #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
                    df1.to_csv(path0+'cardu'+card_name[0]+'權益.csv', index = False)
                    df.to_csv(path0+'cardu'+card_name[0]+'.csv', index = False) 
            
    else:
        for i in range(len(card_link)):
            driver.get(card_link[i]) #自動打開網頁（不要關）
            print(card_name[i])
            time.sleep(3) #暫停
            soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
            
            #卡圖片
            card_img = []
            result = soup.find('img', class_='ccard_img')
            if result !=None:
                card_img.append(result.get('src'))
                print(result.get('src'))
                
                #申請連結
                card_apply_link = []
                result = soup.find('a', class_='btn btn-block warning-layered btnOver')
                if result != None:
                    card_apply_link.append(result.get('href'))
                    print(result.get('href'))
                else:
                    card_apply_link.append('無')
                           
                #優惠
                summary_title = []
                summary_text = []
                results = soup.find_all('div', class_='col-md-6 py-1')
                for result in results:
                    print(result.text)
                    summary_text.append(result.text[:-1])
                    summary_title.append('特色')
                           
                #全部權益           
                button= driver.find_element(By.ID, "special_3-tab") 
                button.click()
                time.sleep(2)  
                soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                           
                #上標題
                title = []
                result = soup.find('form', class_='credit_boot')
                result1 = result.find_all('th')
                for result in result1:
                    print(result.text[:4])
                    title.append(result.text[:4])
                    
                #內文
                title_list = [] #標題
                text_list = [] #內容
                #result2 = soup.find('table')
                #print(result2)
                result3 = soup.find('div', id ='special_3')
                result2 = result3.find('tbody')
                #print(result2)
                result2 = result2.find_all('tr')
                for result in result2:
                    i = 0
                    results = result.find_all('td')
                    for result in results:
                        if i == 0:
                            print(result.find('label').text)
                            title_list.append(result.find('label').text)
                        else:
                            print(result.text)
                            text_list.append(result.text)
                        i+=1
                keyword='、'.join(summary_text) #把大標當關鍵字
    
                card_dict = { 
                    '卡圖片':card_img,
                    '申請連結':card_apply_link,
                    summary_title[0]:keyword
                }
                
                card_dict1={
                    title[0]:title_list,
                    title[1]:text_list
                }
                
                df1 = pd.DataFrame(card_dict1)
                df = pd.DataFrame(card_dict)
                folder_name = 'carducsv'+card_ranking_type[k]
                path = "/Users/takoyaki/Downloads/專題爬蟲"  
        
                folder_path = os.path.join(path, folder_name)
                if not os.path.isdir(folder_path):
                    os.makedirs(folder_path, mode=0o777)
                path0 = str(path+'/'+folder_name+"/")
                #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
                
                df1.to_csv(path0+'icardu'+card_name[0]+'權益.csv', index = False)
                df.to_csv(path0+'icardu'+card_name[0]+'.csv', index = False)
                
            else:
                cards = soup.find_all('a', class_='card_name my-2')
                for card in cards:
                    card_img = []
                    driver.get('https://www.cardu.com.tw'+card.get('href')[2:]) #自動打開網頁（不要關）
                    time.sleep(3) #暫停
                    soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                    
                    result = soup.find('img', class_='ccard_img')
                    card_img.append(result.get('src'))
                    print(result.get('src'))
                    
                    #申請連結
                    card_apply_link = []
                    result = soup.find('a', class_='btn btn-block warning-layered btnOver')
                    if result != None:
                        card_apply_link.append(result.get('href'))
                        print(result.get('href'))
                    else:
                        card_apply_link.append('無')
                               
                    #優惠
                    summary_title = []
                    summary_text = []
                    results = soup.find_all('div', class_='col-md-6 py-1')
                    for result in results:
                        print(result.text)
                        summary_text.append(result.text[:-1])
                        summary_title.append('特色')
                               
                    #全部權益           
                    button= driver.find_element(By.ID, "special_3-tab") 
                    button.click()
                    time.sleep(2)  
                    soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
                               
                    #上標題
                    title = []
                    result = soup.find('form', class_='credit_boot')
                    result1 = result.find_all('th')
                    for result in result1:
                        print(result.text[:4])
                        title.append(result.text[:4])
                        
                    #內文
                    title_list = [] #標題
                    text_list = [] #內容
                    #result2 = soup.find('table')
                    #print(result2)
                    result3 = soup.find('div', id ='special_3')
                    result2 = result3.find('tbody')
                    #print(result2)
                    result2 = result2.find_all('tr')
                    for result in result2:
                        i = 0
                        results = result.find_all('td')
                        for result in results:
                            if i == 0:
                                print(result.find('label').text)
                                title_list.append(result.find('label').text)
                            else:
                                print(result.text)
                                text_list.append(result.text)
                            i+=1
                    keyword='、'.join(summary_text) #把大標當關鍵字
        
                    card_dict = { 
                        '卡圖片':card_img,
                        '申請連結':card_apply_link,
                        summary_title[0]:keyword
                    }
                    
                    card_dict1={
                        title[0]:title_list,
                        title[1]:text_list
                    }
                    
                    df1 = pd.DataFrame(card_dict1)
                    df = pd.DataFrame(card_dict)
                    folder_name = 'carducsv'+card_ranking_type[k]
                    path = "/Users/takoyaki/Downloads/專題爬蟲"  
            
                    folder_path = os.path.join(path, folder_name)
                    if not os.path.isdir(folder_path):
                        os.makedirs(folder_path, mode=0o777)
                    path0 = str(path+'/'+folder_name+"/")
                    #path='/Users/takoyaki/Downloads/專題爬蟲/carducsv/'
                    
                    df1.to_csv(path0+'icardu'+card_name[0]+'權益.csv', index = False)
                    df.to_csv(path0+'icardu'+card_name[0]+'.csv', index = False)
# Out:
# ☆現金回饋
# 國內回饋
# 國外回饋
# 其他卡片
# 聯邦銀行吉鶴卡JCB_晶緻卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3683&cc_group_id=1468
# 花旗銀行現金回饋PLUS卡MasterCard_鈦金卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3596&cc_group_id=1386
# 永豐銀行幣倍卡MasterCard_鈦金卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3366&cc_group_id=1269
# 華南銀行超鑽現金回饋卡VISA_無限卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3667&cc_group_id=1456
# 華南銀行超鑽現金回饋卡JCB_晶緻卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3669&cc_group_id=1456
# 星展銀行eco永續卡MasterCard_鈦金商務卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3615&cc_group_id=1421
# 上海銀行小小兵Bello回饋卡MasterCard商務鈦金卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3564&cc_group_id=1393
# 滙豐銀行現金回饋御璽卡VISA御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3359&cc_group_id=1266
# 星展銀行炫晶Live Fresh卡VISA_商務御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3611&cc_group_id=1359
# 元大銀行鑽金智富iPASS聯名卡VISA_商務御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3651&cc_group_id=1444
#
#
# 凱基銀行魔FUN悠遊御璽卡VISA_御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3474&cc_group_id=1332
# 台中銀行MySense悠遊御璽卡VISA_御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3642&cc_group_id=1437
# 玉山銀行U Bear 信用卡MasterCard_鈦金商務卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3572&cc_group_id=1399
# 中國信託英雄聯盟信用卡MasterCard_鈦金商務卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3629&cc_group_id=1428
# 新光銀行寰宇現金回饋卡MasterCard_鈦金卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3434&cc_group_id=1307
# 聯邦銀行綠卡VISA_御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3650&cc_group_id=1443
# 凱基銀行魔BUY悠遊鈦金卡MasterCard_鈦金卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3602&cc_group_id=1418
# 星展銀行eco永續卡MasterCard_鈦金商務卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3615&cc_group_id=1421
# 彰化銀行 My購卡MasterCard_鈦金商務卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3644&cc_group_id=1439
# 永豐銀行DAWHO現金回饋信用卡VISA商務御璽卡
# https://www.cardu.com.tw/card/card_info.php?cc_pk=3570&cc_group_id=1397
# 0
# 國內回饋:2%
# 其他卡片:無
# 國外回饋:1%
# 1
# 國內回饋:2%
# 其他卡片:無
# 國外回饋:2%
# 2
# 國內回饋:2%
# 其他卡片:無
# 國外回饋:3%
# 3
# 國內回饋:2%
# 其他卡片:無
# 國外回饋:4%
# 4
# 國內回饋:2%
# 其他卡片:
# 國外回饋:3.4%
# 5
# 國內回饋:2%
# 其他卡片:無
# 國外回饋:2.55%
# 6
# 國內回饋:1.234%
# 其他卡片:無
# 國外回饋:2.234%
# 7
# 國內回饋:1.22%
# 其他卡片:無
# 國外回饋:2.22%
# 8
# 國內回饋:1.2%
# 其他卡片:無
# 國外回饋:2.52%
# 9
# 國內回饋:1.2%
# 其他卡片:無
# 國外回饋:2.2%
# 10
# 國內回饋:連鎖影城、指定線上影音50%
# 其他卡片:當期結帳新增一般消費3,000元(含)以上可享優惠
# 國外回饋:0.5%
#
#
# 11
# 國內回饋:指定通路最高20%
# 其他卡片:當期帳單一般消費達2,000元(不含指定通路)
# 國外回饋:1.5%
# 12
# 國內回饋:指定通路最高12%
# 其他卡片:網購每期回饋上限200元；指定娛樂/影音平台每期上限200元。
# 國外回饋:指定通路最高12%
# 13
# 國內回饋:指定數位通路最高 10%
# 其他卡片:指定網購通路當期須累積滿5,000元，每戶上限NT500元/月；其他數位通路每戶..
# 國外回饋:指定數位通路最高 10%
# 14
# 國內回饋:指定行動支付/數位消費最高 10%
# 其他卡片:My FamiPay 10% (上限100元/月)
# 指定數位消費3% (上限5..
# 國外回饋:3%
# 15
# 國內回饋:綠色通路10%
# 其他卡片:需申請電子帳單，電動車族月上限200元；共享交通月上限100元；低碳飲食月上限1..
# 國外回饋:3%
# 16
# 國內回饋:指定行動支付8%
# 其他卡片:Apple Pay、Google Pay、LINE Pay、街口、悠遊付、OPE..
# 國外回饋:指定行動支付9.3%
# 17
# 國內回饋:指定通路最高8%
# 其他卡片:國內回饋含卡片原始回饋及上市加碼優惠；國外回饋未滿NT$2萬則僅有2.55%
# 國外回饋:3%
# 18
# 國內回饋:指定通路週末最高8%
# 其他卡片:網購加碼回饋上限300元；指定通路加碼上限200元
# 國外回饋:指定通路週末最高8%
# 19
# 國內回饋:指定通路7%
# 其他卡片:綁定數位帳戶自動扣繳及電子帳單
# 國外回饋:指定通路8%
#
#
# 聯邦銀行吉鶴卡JCB_晶緻卡
# https://imgcloud.cardu.com.tw/201910/20220727/credit/16/Cardu20220727105947.png
# http://cardu.cc/聯邦吉鶴卡22_線上辦卡
# 海外首發日本QUICPay感應支付
#
# 日本使用Apple Pay最高5%
#
# 日幣消費3.5%回饋無上限
#
# 日本指定網購平台5%
#
# 國內指定日系美饌最高現折10%
# 權益項目
# 內容說明
# 申辦條件
# 1.正卡18歲以上，具正當職業並提供相關財力證明。
# 2.附卡15歲以上，且為正卡持卡人之父母、配偶、配偶父母、兄弟姐妹、子女。
# 年費
# 正卡：1,000元，附卡：1,000元
# 正卡第一年免年費，自核卡日起每年刷卡消費10,000元以上或不限金額刷卡10次以上，或申辦電子化帳單(電子/行動帳單)成功且有效期間，享正附卡次年免年費。
# 循環起息日
# 入帳日起。
# 循環利息
# 差別利率：5%~15%
# 定期檢視頻率：3個月
# 現金回饋
# 國內消費2%現金回饋無上限
# 日本地區消費3.5%現金回饋無上限
# 其他國家消費1%現金回饋無上限
# 綁定 Apple Pay 於日本國內商店感應交易加碼1.5%回饋(月上限1,000元)
# 指定日本網購以日幣結帳請款加碼1.5%回饋(月上限500元)
# 國內指定日系名店消費，享活動加碼 4% (月上限500元)
#
# ．指定日本網購：日本樂天(Rakuten)、日本亞馬遜(Amazon.co.jp)
# ．日系美饌最高現折10%、日系旅館享住宿泡湯優惠
# 旅遊保險
# 1.旅遊平安險：2,000萬元。
# 2.旅遊不便險：班機延誤1萬元、行李延誤1萬元、行李遺失3萬元、劫機險5000元等。
# 3.個人責任保險：10萬元。
# 機場停車優惠
# 每人每年限使用3次，每次最高可停6天，
# 使用服務前1年新增一般消費達6萬元以上可使用1次。
# (全國加油聯名卡不含全國加油站消費金額)
# 卡優首刷禮
# ●活動時間：~2023/07/31
# ●活動對象：新戶申辦聯邦銀行指定信用卡
# ●活動辦法：於活動時間內透過卡優專屬連結申辦聯邦銀行指定信用卡正卡，且核卡後30天內任刷1筆可獲得「兩大超商二選一200元購物金」(7-11/全家，兩大品牌擇一使用)。
#
# 指定信用卡：賴點卡、綠卡、幸福M卡、吉鶴卡
#
# ※注意事項：
# 1.新戶定義為核卡前六個月內未曾持有任何一聯邦信用卡者。
# 2.活動期間提供之「兩大超商二選一200元購物金」，每歸戶限領1份，正附卡合併計算，將於符合資格後次月月底前陸續以簡訊方式發送兌換序號，寄送至符合資格之正卡持卡人留存於聯邦銀行之手機門號 。兌換序號使用期限及使用方式詳電子票券說明，逾期失效恕不補發。
# 3.符合活動資格的客戶，不再適用其他通路加碼、專案或卡友推薦活動，亦不得重覆參加。
# 4.聯邦銀行保留審核信用卡持卡人參加本活動資格及修改或變更本活動內容之權利。
# 刷卡禮
# 【新戶首刷禮500元刷卡金│20吋登機箱】
#
# 活動期間：2023/07/01~09/30
# 新戶核卡後30日內，消費累積滿1,288元(含)以上，享首刷好禮二選一：
# 《刷卡金500元》或《20吋銀河灰登機箱》
# 國外簽帳消費手續費
# 1.5%。計算方式如下：
# 各信用卡國際組織手續費1%+本行國外交易服務費為0.5%。
# 功能特色
# 日本海外全球首發QUICPay，在日本可使用原本手機的 Apple Pay ，直接感應支付
# 花旗銀行現金回饋PLUS卡MasterCard_鈦金卡
# https://imgcloud.cardu.com.tw/201910/20200326/credit/26/Cardu20200326100780.png
# 國內外享2%現金回饋
#
# 威秀影城購票6折起
#
# 首年免年費
# 權益項目
# 內容說明
# 申辦條件
# 1.正卡18歲~75歲，固定年收入27萬元以上(非學生)。
# 2.附卡15歲~75歲，且為正卡持卡人之父母、配偶、配偶父母、兄弟姐妹、子女。
# 年費
# 正卡2400元(首年免年費)；附卡免年費。 次年免年費條件：前一年累積消費60,000元或累積消費12次。
# 循環起息日
# 入帳日起。
# 循環利息
# 6.88%~15%
# 逾期違約金
# 依下列方式計收違約金：
# 當期繳款發生延滯時，違約金300元；連續2期發生繳款延滯時，違約金400元；連續3期發生繳款延滯時，違約金500元。未繳清金額不足1,000元，無需繳交逾期違約金。
# 預借現金
# 預借現金手續費：（每筆預借金額 × 3.5％) ＋100元。
# 現金回饋
# 國內外一般消費，不限通路享2%現金回饋，每年最高回饋NT$6萬
# 掛失自負
# 失卡零風險：失卡立刻掛失後，花旗銀行將於24小時緊急核發新卡。
# 掛失補卡費用
# 掛失手續費：200元。
# 國外簽帳消費手續費
# 1.5%。計算方式如下：
# 各信用卡國際組織手續費1%+本行國外交易服務費為0.5%。
# 永豐銀行幣倍卡MasterCard_鈦金卡
# https://imgcloud.cardu.com.tw/201910/20200430/credit/19/Cardu20200430114939.gif
# http://cardu.cc/永豐幣倍卡Q2_線上辦卡
# 消費最高10%現金回饋
#
# 國外消費最高3%無上限
#
# 旅遊通路/海外網購最高7%
#
# 新戶首刷最高享900元購物金
# 權益項目
# 內容說明
# 申辦條件
# 正卡申請人：年滿18歲以上、70歲以下者。
# 附卡申請人：年滿15歲以上、70歲以下者，限為正卡申請人之配偶、子女、父母、兄弟姊妹及配偶之父母。
# 年費
# 正卡3,000元，附卡：1,500元。
# 首年免年費，前12個月累積消費滿36,000元或消費12次或申請信用卡電子對帳單且取消實體帳單，免收次年年費。
# 附卡6張以內免年費
# 循環起息日
# 入帳日起。
# 循環利息
# 2.74%~15%
# 逾期違約金
# 未依約繳款當月之違約金為新台幣300元；連續第二個月未依約繳款之違約金為新台幣400元；連續第三個月未依約繳款之違約金為新台幣500元（若當期未結清「得計入循環信用本金之帳款」金額低於或等於新臺幣玖佰拾玖元者不收取違約金）。每次最多連續收取三個月。
# 預借現金
# 每筆預借現金金額×3.5%＋＄100元
# 現金回饋
# 國內1%、國外2%回饋無上限。
# 完成指定任務享任務加碼及精選通路加碼：
#
# 【任務一】綁定電子或行動帳單且設定永豐臺外幣帳戶自動扣繳帳款且扣款成功
# ※若您於永豐數位帳戶開戶且同時申辦幣倍卡，則您已符合任務一
#
# 【任務二】與永豐往來符合以下任一且達等值臺幣金額1元以上~
# ①外幣存款月平均餘額或
# ②臺外幣帳戶間換匯單筆金額或
# ③臨櫃投保外幣保單月扣繳單筆金額
# ※1元~10萬元屬【懂匯】資格；10萬元以上屬【超匯】資格
#
# 【任務加碼】
# 國內一般消費加碼1%，【懂匯】上限100元、【超匯】上限300元
# 國外一般消費加碼1%，【懂匯】上限100元、【超匯】無上限
#
# 【精選通路加碼】
# 海外網購/旅遊通路加碼4%，【懂匯】上限150元、【超匯】上限300元
#
# ◆海外網購：Amazon、淘寶、 Dokodemo 多和夢、 Lookfantastic、Selfridges、Farfetch、CASETiFY、DAIKOKUDRUG、eBay、Shopbop、ZALORA、ASOS、iHerb、Gmarket、Yoox 、 Moosejaw、YesStyle。
#
# ◆旅遊通路：旅行社(含Agoda、Booking.com、易遊網、雄獅旅行社等)、飯店類(含飯店、渡假村、旅館民宿，不含餐廳類消費)消費。以上皆係以消費商店所屬收單機構登記之行業代號為判斷依據，倘因於收單機構登記之行業代號與實際營業項目不符時，仍以收單機構登記之行業代號為準，實際依系統判定為準。
# 旅遊保險
# 支付本人當次出國機票全額或80%以上旅遊團團費
# 1.旅行平安險：3,500萬元
# 2.旅行不便險：
# 班機延誤1萬元、
# 行李延誤1萬元、
# 行李遺失3萬元、
# 劫機險5000元、
# 旅行文件重置費1萬元。
# 3.傷害醫療險：30萬元
# 4.移靈費用(實支實付)：3萬元
# 機場接送
# 支付當次出國機票全額或8成以上旅遊團費，金額須滿1萬元以上。
# 前一年度歸戶累積消費180,000元~359,999元，享1次接或送服務。
# 前一年度歸戶累積消費360,000元以上，享2次接或送服務。
# 機場貴賓室
# 刷卡支付本人當次出國機票全額或80％以上之旅遊團費單筆達NT$3萬以上，2個月內可免費使用2次，每年6次。
# 機場停車優惠
# 當次出國前，支付機票全額或80%以上旅遊團費，可享有正附卡持卡人，合計一年3次、每次最長7天之台灣桃園國際機場及小港國際機場外圍停車場免費停車服務。
#
# 24小時服務專線：0800-058-888，
# 客服專線：(02)2528-7776。
# 購物保障
# 刷卡日起三十天內，持卡人須負擔自負額為每次損失之50%，最低500元，每件物品最高不超過30,000元整，每次事故合計最高不超過100,000元整，每卡於保險期間累計最高賠償金額200,000元整。
# 卡優首刷禮
# 【卡優加碼首刷禮200元】
# 一、活動時間：2023/7/1~2023/8/31
# 二、活動對象：新申辦永豐幣倍卡(限新戶)
# 三、活動辦法：新戶於活動時間內透過卡優專屬連結申辦幣倍卡正卡，且核卡後30天內累積消費達400元，即可獲得「兩大超商二選一200元電子購物金」(7-11、全家，兩大品牌擇一使用) 。
#
# 四、注意事項
# 1.適用對象：申辦前六個月內未持有永豐銀行任一信用卡正卡者。
# 2.本活動須於2023年08月31日(含)前進件且於2023年9月15日(含)前核卡，且核卡後30天內累積消費達400元，始符合活動資格(進件及核卡日期皆以銀行系統註記之建檔日為準)。
# 3.活動所提供「兩大超商二選一200元電子購物金」，每歸戶限領1份，將於符合首刷資格後2023/11月起陸續以簡訊方式發送兌換序號，寄送至符合資格之正卡持卡人留存於永豐銀行之手機門號 。惟寄送時正卡持卡人須至少持有一張有效卡，且無遭限制或停止使用、延遲繳款或其他違反信用卡約定條款之情事。
# 4.符合首刷禮活動資格的客戶，不再適用永豐銀行MGM活動、其他通路或專案行銷活動。
# 5.持卡人若因任何理由取消刷卡交易或因簽單爭議至消費金額未達本活動門檻，或以違反誠信之方式取得本活動回饋者，永豐銀行保留取消回饋之權利，不另行通知。
# 6.永豐銀行保留隨時修改、變更、取消本活動之權利。
# 刷卡禮
# ●新戶刷卡滿額贈【特選通路購物金500元】
# 活動期間：即日起 ~2023/12/31
# 新戶申辦幣倍卡，核卡後30天內一般消費或全聯福利中心消費【刷3筆各滿599元】或【綁定6大行動支付累積消費滿1,000元】即可獲贈「特選通路購物金500元」。
#
# ●新戶首刷加碼禮【200元7-11購物金】
# 活動期間：即日起 ~2023/12/31
# 新戶申辦幣倍卡，核卡30天內一般消費「綁定6大行動支付累積刷888元」，享加碼贈「200元7-ELEVEN購物金」乙份。(電子禮券，限量2,000份，需登錄)
# 掛失自負
# 銀行負擔自辦理掛失停用手續時起被冒用所發生之損失。
# 掛失補卡費用
# 掛失手續費：200元。
# 國外簽帳消費手續費
# 1.5%。計算方式如下：
# 各信用卡國際組織手續費1%+本行國外交易服務費為0.5%。
# 調閱簽帳單費用
# 國內消費每筆手續費NT$100，國外消費每筆手續費NT$150。
# 緊急替代卡手續費
# 依各信用卡國際組織規定。
# 溢付款退回匯款處理費
# 持卡人申請領回溢繳款時需負擔手續費，退回持卡人銀行帳戶或開立支票者每筆均為NT$100。
# 補寄帳單費用
# 補發二個月之前帳單，每月份帳單收新台幣150元手續費。若超過六個月以上之帳單，無法提供
# 華南銀行超鑽現金回饋卡VISA_無限卡
# https://imgcloud.cardu.com.tw/201910/20220425/credit/16/Cardu20220425174550.jpg
# 國內最高2%現金回饋
#
# 國外最高3.2%現金回饋
#
# 指定稅費免手續費
# 權益項目
# 內容說明
# 申辦條件
# 正卡年滿18歲且年收入120萬元以上；附卡15歲以上，且為正卡持卡人之父母、配偶、配偶父母、兄弟姐妹、子女。
# 年費
# 正卡年費NT$12,000，附卡免年費。
# 正卡首年免年費，自核卡日起，於首年內消費每滿NT$10,000元，可抵扣次年年費1,000元，至全部年費抵扣完為止(年刷NT$120,000免次年年費)，往後年費收費標準依此類推。
# 現金回饋
# 1.國內消費1%現金回饋
# 2.國外消費2.2%現金回饋
# 3.完成下列任務中任三項，加碼1%回饋：(當期帳單加碼回饋上限NT$2,000)
# (1)申請自動扣繳且扣款成功
# (2)綁定本行Line個人化服務且於華銀支付綁定超鑽卡
# (3)使用電子帳單
# (4)使用超鑽卡扣繳公用事業費用
# (5)使用超鑽卡定期定額扣基金
# 機場貴賓室
# 每年可尊享3次【龍騰卡貴賓室/全球5日免費漫遊上網，擇一使用】優惠服務，支付80%以上旅遊團費或全額機票之單筆刷卡金額達 NT$20,000以上，當次航程可使用1次；或單筆刷卡金額達 NT$8,000以上，且當年度帳單累計一般消費金額每達NT$100,000 (含當次團費)，得免費使用1次服務；累計NT$200,000 (含當次團費)，得免費使用2次服務(須有2筆符合資格之團費或機票)，以此類推。
#
# 優惠期間至民國110年12月31日止
# 機場停車優惠
# 支付當次80%以上國外旅遊團費、國外機票，且金額達1萬元以上，可享不限次，一年30天之免費。
# ■桃園機場-五福停車場、五福三場(大園)停車場
# ■高雄機場-大鵬國際停車場
# 優惠期間至民國110年12月31日
# 華南銀行超鑽現金回饋卡JCB_晶緻卡
# https://imgcloud.cardu.com.tw/201910/20220425/credit/29/Cardu20220425174596.jpg
# 國內最高2%現金回饋
#
# 國外最高2.6%現金回饋
#
# 指定稅費免手續費
# 權益項目
# 內容說明
# 申辦條件
# 正卡18歲以上有正當職業即可申請；附卡15歲以上，且為正卡持卡人之父母、配偶、配偶父母、兄弟姐妹、子女。
# 年費
# 正卡：1,200，附卡免年費，
# 首年免年費，自核卡日起，每年不限金額消費3筆，或申請電子帳單後每年不限金額消費1筆，即免收該卡次年年費。
# 現金回饋
# 1.國內消費1%現金回饋
# 2.國外消費1.6%現金回饋
# 3.完成下列任務中任三項，加碼1%回饋：(當期帳單加碼回饋上限NT$2,000)
# (1)申請自動扣繳且扣款成功
# (2)綁定本行Line個人化服務且於華銀支付綁定超鑽卡
# (3)使用電子帳單
# (4)使用超鑽卡扣繳公用事業費用
# (5)使用超鑽卡定期定額扣基金
# 機場貴賓室
# 每年可尊享3次【龍騰卡貴賓室/全球5日免費漫遊上網，擇一使用】優惠服務，支付80%以上旅遊團費或全額機票之單筆刷卡金額達 NT$20,000以上，當次航程可使用1次；或單筆刷卡金額達 NT$8,000以上，且當年度帳單累計一般消費金額每達NT$100,000 (含當次團費)，得免費使用1次服務；累計NT$200,000 (含當次團費)，得免費使用2次服務(須有2筆符合資格之團費或機票)，以此類推。
#
# 優惠期間至民國110年12月31日止
# 機場停車優惠
# 支付當次80%以上國外旅遊團費、國外機票，且金額達1萬元以上，可享每次最多7天，一年21天之免費。
# ■桃園機場-五福停車場、五福三場(大園)停車場
# ■高雄機場-大鵬國際停車場
# 優惠期間至民國110年12月31日
# 星展銀行eco永續卡MasterCard_鈦金商務卡
# https://imgcloud.cardu.com.tw/201910/20200713/credit/30/Cardu20200713175368.png
# 國內、保費消費最高享2%回饋
#
# 國外消費最高享3%回饋無上限
#
# 共享汽機車租借最高享7%回饋
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p_/z4pd9wrd7gvbyqbb3wwff6880000gn/T/ipykernel_1709/4248304758.py in <module>
#     295                 button= driver.find_element(By.ID, "special_3-tab")
#     296                 button.click()
# --> 297                 time.sleep(2)
#     298                 soup = BeautifulSoup(driver.page_source, 'html.parser') #把script變成美麗湯可讀
#     299
#
# KeyboardInterrupt:
